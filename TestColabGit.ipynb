# %%
from google.colab import userdata
gitpat = userdata.get('githubPAT')
user = "JavierMariosa"
repo = "testvscodecolab"

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/JavierMariosa/testvscodecolab.git
# Out:
# Cloning into 'testvscodecolab'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 1), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/testvscodecolab/
# Out:
# /content/testvscodecolab

# %%
# !git remote set-url origin https://{gitpat}@github.com/{user}/{repo}.git

# %%
# %pwd
# Out:
# '/content/testvscodecolab'

# %%
# !git config --global user.email "javier.mariosa@gmail.com"
# !git config --global user.name "Javier"

# %%
# !git add test.py

# %%
# !git commit -m "test2"
# Out:
# [main d488e4b] test2
#  1 file changed, 2 insertions(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 276 bytes | 276.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/JavierMariosa/testvscodecolab.git
#    b23deff..d488e4b  main -> main

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 965 bytes | 965.00 KiB/s, done.
# From https://github.com/JavierMariosa/testvscodecolab
#    d488e4b..8f450c3  main       -> origin/main
# Updating d488e4b..8f450c3
# Fast-forward
#  test.py | 4 +++-
#  1 file changed, 3 insertions(+), 1 deletion(-)
